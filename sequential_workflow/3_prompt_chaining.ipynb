# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI()

# %%
class BlogState(TypedDict):
     title: str
     outline: str
     content: str

# %%
def create_outline(state: BlogState) -> BlogState:
    title = state['title']
    
    prompt = f'Generate an outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content
    state['outline'] = outline
    return state

# %%
def create_blog(state:BlogState) -> BlogState:
    
    title = state['title']
    outline = state['outline']
    prompt = f'Write a detailed blog on the title {title} using the following outline {outline}'
    content = model.invoke(prompt).content
    state['content'] = content
    return state

# %%
graph = StateGraph(BlogState)

graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

# %%
graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)
workflow = graph.compile()

# %%
initial_state = {'title': "Risee of AI in Pakistan"}
final_state = workflow.invoke(initial_state)
print(final_state['content'])
# Out:
# I. Introduction
#
# Artificial Intelligence (AI) is the simulation of human intelligence processes by machines, primarily computer systems. It encompasses technologies such as machine learning, natural language processing, and computer vision, among others. In Pakistan, AI is gaining traction across various industries, with businesses and organizations increasingly leveraging its capabilities to enhance operations and improve efficiency.
#
# II. The Growth of AI in Pakistan
#
# A. Adoption of AI in Various Industries
#
# AI is being adopted in a variety of industries in Pakistan, including healthcare, finance, agriculture, and education. In healthcare, AI is being used for medical imaging analysis, disease diagnosis, and personalized treatment recommendations. In finance, AI is helping to automate processes such as fraud detection, risk assessment, and customer service. In agriculture, AI is being used for crop monitoring, yield prediction, and pest management. In education, AI is being employed for personalized learning, student assessment, and administrative tasks.
#
# B. Government Initiatives to Promote AI Development
#
# The government of Pakistan has also taken steps to promote AI development in the country. The National Center for Artificial Intelligence (NCAI) has been established to spearhead research and development in AI. Various initiatives such as funding support, incubation centers, and collaboration programs are being implemented to support AI startups and entrepreneurs. Additionally, the government is working on policies and regulations to facilitate the responsible and ethical use of AI technologies.
#
# C. Collaboration Between Academia and Industry to Advance AI Research
#
# Collaboration between academia and industry is playing a crucial role in advancing AI research in Pakistan. Universities are offering programs in AI and collaborating with industry partners on research projects and technology transfer. This collaboration is not only enhancing the skills and expertise of the workforce but also fueling innovation and the development of AI solutions tailored to local needs.
#
# III. Impact of AI on Society
#
# A. Job Displacement and Creation
#
# While AI has the potential to automate certain tasks and jobs, leading to concerns about job displacement, it also creates opportunities for new roles and industries. In Pakistan, AI is expected to create new jobs in AI development, data science, and related fields, which require specialized skills and expertise. It is essential for individuals to upskill and reskill to stay relevant in the evolving job market.
#
# B. Ethical Considerations in the Use of AI
#
# As AI becomes more pervasive in society, ethical considerations regarding privacy, bias, and accountability become more critical. It is essential for organizations and policymakers to ensure that AI technologies are deployed responsibly and ethically, considering the impact on individuals and society at large. Transparency, fairness, and inclusivity should be prioritized in AI development and deployment.
#
# C. Opportunities for Economic Growth
#
# AI presents significant opportunities for economic growth in Pakistan. By harnessing the power of AI technologies, businesses can enhance productivity, optimize processes, and deliver innovative products and services to the market. The growth of AI industries can also create a ripple effect, generating employment, attracting investments, and driving economic development in the country.
#
# IV. Challenges and Barriers to AI Adoption in Pakistan
#
# A. Lack of Skilled Workforce
#
# One of the significant challenges in the adoption of AI in Pakistan is the shortage of skilled professionals with expertise in AI and related fields. There is a gap between the demand for AI talent and the supply of qualified individuals, leading to recruitment challenges for organizations looking to implement AI solutions. It is crucial to invest in education and training programs to develop a skilled AI workforce in the country.
#
# B. Infrastructure Limitations
#
# The development and deployment of AI technologies require robust infrastructure in terms of computing power, data storage, and connectivity. In Pakistan, infrastructure limitations, such as inadequate internet coverage and power outages, can hinder the scalability and efficiency of AI applications. Investments in infrastructure development are necessary to support the growth of AI technologies across the country.
#
# C. Data Privacy and Security Concerns
#
# Data privacy and security are significant concerns in the use of AI technologies, particularly considering the sensitivity of personal and confidential information. In Pakistan, there is a need for regulations and frameworks to protect data rights and ensure cybersecurity in AI applications. Organizations must prioritize data protection measures and compliance with data privacy laws to mitigate risks and build trust with stakeholders.
#
# V. Future Outlook for AI in Pakistan
#
# A. Potential Areas for AI Growth and Development
#
# Looking ahead, there are several potential areas for AI growth and development in Pakistan. Industries such as e-commerce, transportation, energy, and public services can benefit from AI applications to drive innovation and efficiency. Emerging technologies like Internet of Things (IoT), blockchain, and robotics can be integrated with AI to create synergies and expand the scope of AI solutions in diverse sectors.
#
# B. Role of Government and Industry in Fostering AI Innovation
#
# The government and industry have a crucial role to play in fostering AI innovation in Pakistan. Collaboration between public and private sectors, academia, and research institutions is essential to create a conducive ecosystem for AI research and development. Investments in research, infrastructure, and talent development are necessary to position Pakistan as a hub for AI innovation and technology adoption.
#
# C. Implications for Society and Economy
#
# The widespread adoption of AI in Pakistan has far-reaching implications for society and the economy. AI technologies can improve the quality of life, enhance productivity, and drive economic growth, but they also pose challenges in terms of ethics, privacy, and job displacement. It is essential for stakeholders to work together to address these issues proactively and harness the benefits of AI for the betterment of society and the economy.
#
# VI. Conclusion
#
# In conclusion, the rise of AI in Pakistan presents a significant opportunity for growth, innovation, and societal impact. The adoption of AI technologies across industries, supported by government initiatives, collaboration between academia and industry, and ethical considerations, can drive progress and prosperity in the country. It is crucial for stakeholders to recognize the potential of AI, address the challenges and barriers, and work towards a sustainable and inclusive AI ecosystem in Pakistan. By investing in skills development, infrastructure, and ethical frameworks, we can leverage the power of AI to create a brighter future for Pakistan.
